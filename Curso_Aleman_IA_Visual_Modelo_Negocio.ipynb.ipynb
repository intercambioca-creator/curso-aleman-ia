# %% [markdown]
# # 🎓 Curso Automatizado de Alemán con IA
# ### Plataforma educativa inteligente para aprendizaje personalizado
# 📅 1 octubre 2025
# 👤 Autor: Alberto

# %% [markdown]
# ## 🧩 Propuesta de valor única
# - Basado en clases reales, no frases aisladas.
# - Detecta intención pedagógica (explicación, práctica, evaluación).
# - Recomendaciones personalizadas por nivel, estilo y progreso.
# - Seguimiento automático, visualización y certificación.
# - Refuerzo visual con imágenes y gráficas por capítulo.

# %%
import pandas as pd

modelo_ingresos = pd.DataFrame({
    "Estrategia": ["Freemium + suscripción", "Venta por módulos", "Licencias institucionales", "Certificación premium"],
    "Descripción": [
        "Acceso gratuito a clases básicas, pago mensual para contenido adaptativo",
        "Cursos temáticos (A1, A2, B1…) con pago único",
        "Venta a colegios, universidades o empresas",
        "Pago por examen y diploma oficial"
    ],
    "Ventajas": [
        "Captura usuarios y convierte por valor",
        "Claridad y control para el usuario",
        "Escalabilidad y reputación",
        "Monetiza el logro del estudiante"
    ]
})
modelo_ingresos
# Out:
#                   Estrategia  \
# 0     Freemium + suscripción
# 1          Venta por módulos
# 2  Licencias institucionales
# 3      Certificación premium
#
#                                          Descripción  \
# 0  Acceso gratuito a clases básicas, pago mensual...
# 1      Cursos temáticos (A1, A2, B1…) con pago único
# 2         Venta a colegios, universidades o empresas
# 3                  Pago por examen y diploma oficial
#
#                                  Ventajas
# 0  Captura usuarios y convierte por valor
# 1      Claridad y control para el usuario
# 2              Escalabilidad y reputación
# 3        Monetiza el logro del estudiante

# %%
benchmarking = pd.DataFrame({
    "Plataforma": ["Duolingo", "Babbel", "Lingoda", "Busuu"],
    "Modelo": ["Freemium + gamificación", "Suscripción mensual", "Clases en vivo + CEFR", "Comunidad + IA"],
    "Diferenciador": ["Repetición espaciada", "Conversación práctica", "Profesores certificados", "Corrección colaborativa"],
    "Tu ventaja": [
        "Clases reales + intención pedagógica",
        "Adaptación por estilo y progreso",
        "Escalabilidad sin clases en vivo",
        "Automatización completa del seguimiento"
    ]
})
benchmarking
# Out:
#   Plataforma                   Modelo            Diferenciador  \
# 0   Duolingo  Freemium + gamificación     Repetición espaciada
# 1     Babbel      Suscripción mensual    Conversación práctica
# 2    Lingoda    Clases en vivo + CEFR  Profesores certificados
# 3      Busuu           Comunidad + IA  Corrección colaborativa
#
#                                 Tu ventaja
# 0     Clases reales + intención pedagógica
# 1         Adaptación por estilo y progreso
# 2         Escalabilidad sin clases en vivo
# 3  Automatización completa del seguimiento

# %% [markdown]
# ## 📈 Estrategia de crecimiento
# - Internacionalización (inglés, alemán, español)
# - Marketing de contenido (tips, visualizaciones, detrás de cámaras)
# - Embajadores educativos (profesores que recomienden el sistema)
# - Gamificación (insignias, niveles, recompensas)
# - IA conversacional integrada (chatbots que practican alemán)

# %% [markdown]
# ## 📣 Pitch comercial
# “¿Quieres aprender alemán con clases reales, adaptadas a tu nivel y estilo de aprendizaje? Nuestra plataforma usa inteligencia artificial para transformar videos educativos en sesiones personalizadas, con seguimiento automático, recomendaciones inteligentes y certificación.”

# %%
from IPython.display import Markdown

Markdown("""
### 👋 Bienvenida, Camila
**Clase recomendada**: Verbos separables (A2)
**Duración**: 4 min 32 seg
**Intención**: Explicación + Práctica
**Recursos**: Glosario visual, Audio nativo
**Progreso**: 12 clases completadas
**Logros**: Certificado en 3 clases
""")
# Out:
# ### 👋 Bienvenida, Camila
# **Clase recomendada**: Verbos separables (A2)
# **Duración**: 4 min 32 seg
# **Intención**: Explicación + Práctica
# **Recursos**: Glosario visual, Audio nativo
# **Progreso**: 12 clases completadas
# **Logros**: Certificado en 3 clases

# %%
perfil = {"nivel": "A2", "estilo": "Visual", "intencion": "Práctica"}

clases = [
    {"tema": "Verbos separables", "nivel": "A2", "estilo": "Visual", "intencion": ["Explicación", "Práctica"]},
    {"tema": "Artículos definidos", "nivel": "A1", "estilo": "Auditivo", "intencion": ["Explicación"]},
    {"tema": "Oraciones subordinadas", "nivel": "B1", "estilo": "Kinestésico", "intencion": ["Evaluación"]}
]

recomendacion = next(
    (c for c in clases if c["nivel"] == perfil["nivel"] and c["estilo"] == perfil["estilo"] and perfil["intencion"] in c["intencion"]),
    None
)

recomendacion
# Out:
# {'tema': 'Verbos separables',
#  'nivel': 'A2',
#  'estilo': 'Visual',
#  'intencion': ['Explicación', 'Práctica']}

# %%
import matplotlib.pyplot as plt

capitulos = ["A1 - Saludos", "A1 - Verbos", "A2 - Preguntas", "A2 - Subordinadas"]
completado = [100, 80, 60, 40]

plt.figure(figsize=(8,4))
plt.barh(capitulos, completado, color="#3498db")
plt.xlabel("Progreso (%)")
plt.title("📈 Avance por capítulo")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## 🖼️ Refuerzo visual en tus clases
# - Verbos separables → línea de tiempo con prefijo + raíz
# - Casos gramaticales → diagrama de declinación por género
# - Vocabulario de comida → collage etiquetado
# - Profesiones → íconos ilustrados con audio
#
# Puedes integrar estas imágenes como tarjetas visuales o recursos interactivos en cada clase.

# %% [markdown]
# ## 🧭 Estructura recomendada para tu landing page
# 1. 🎓 Hero section
# 2. 🧩 Propuesta de valor
# 3. 📚 Cómo funciona
# 4. 💬 Testimonios
# 5. 💼 Planes y precios
# 6. 📣 Llamado a la acción

# %% [markdown]
# ## 📣 ¿Listo para transformar la enseñanza del alemán?
# 🌍 Aprende desde cualquier lugar
# Con tecnología que entiende cómo aprendes
# [Botón: Comienza gratis] [Botón: Solicita demo institucional]
